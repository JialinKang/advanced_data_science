# %% [markdown]
# <a href="https://colab.research.google.com/github/JialinKang/advanced_data_science/blob/master/homework6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import file from google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
# !pwd
# os.chdir('Anyfile Notepad Files')
# Out:
# /content/drive/My Drive/Anyfile Notepad Files

# %%
file_path = '/content/drive/My Drive/Anyfile Notepad Files/shhs1.txt'

# %% [markdown]
# **Question 1**

# %%
import pandas as pd
from pandas.core.frame import DataFrame
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

table = pd.read_table(file_path)

data = DataFrame(table)
j = 0
ls = []
for i in data['bmi_s1']:
  if math.isnan(i):
    ls.append(j)
  j = j + 1

# %%
data.drop(ls, inplace=True)
for i in data_pre['bmi_s1']:
  if math.isnan(i):
    print(i)

# %%
lrModel = LinearRegression()
lrModel.fit(data[['bmi_s1']], np.log(data[['rdi4p']]+1))
alpha = lrModel.intercept_

beta = lrModel.coef_
print(alpha, beta)
# Out:
# [-0.4630414] [[0.07648599]]

# %%
y = np.log(data['rdi4p'] + 1)
x = data['bmi_s1']
x_line = np.linspace(18, 50, 200)
y_line = 0.07648599*x_line - 0.4630414
plt.scatter(x, y, alpha=0.5, s = 1)
plt.plot(x_line, y_line, c = 'red')
plt.title('scatterplot with the fitted line')
plt.xlabel('bmi')
plt.ylabel('log(rdi4p+1)')
plt.show()

# %% [markdown]
# **Question 2**

# %%
import math
math.exp(1)**(30*0.07648599- 0.4630414) - 1
# Out:
# 5.243483625986552

# %% [markdown]
# so rdi4p for a person with a bmi = 30 is 5.24
